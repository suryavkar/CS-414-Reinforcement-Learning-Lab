# %%
import gym
import numpy as np
from itertools import count
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical

gamma = 0.95
seed = 543
render = False
log_interval = 10

env = gym.make('CartPole-v0')
# env._max_episode_steps = 1000
env.seed(seed)
torch.manual_seed(seed)


class Policy(nn.Module):
    def __init__(self):
        super(Policy, self).__init__()
        self.linear1 = nn.Linear(4, 256)
        self.linear2 = nn.Linear(256, 2)

        self.saved_log_probs = []
        self.rewards = []

    def forward(self, x):
        x = F.relu(self.linear1(x))
        action_scores = self.linear2(x)
        return F.softmax(action_scores, dim=1)


policy = Policy()
optimizer = optim.Adam(policy.parameters(), lr=1e-2)
eps = np.finfo(np.float32).eps.item()
rew_ep = []

def select_action(state):
    state = torch.from_numpy(state).float().unsqueeze(0)
    probs = policy(state)
    m = Categorical(probs)
    action = m.sample()
    policy.saved_log_probs.append(m.log_prob(action))
    return action.item()


def finish_episode(b):
    R = 0
    policy_loss = []
    rewards = []
    for r in policy.rewards[::-1]:
        R = r + gamma * R
        rewards.insert(0, R)
    rewards = torch.tensor(rewards)
    rewards = (rewards - rewards.mean()) / (rewards.std() + eps)
#     print(rewards)
    for log_prob, reward in zip(policy.saved_log_probs, rewards):
        policy_loss.append(-log_prob * (reward))
    optimizer.zero_grad()
    policy_loss = torch.cat(policy_loss).sum()
    policy_loss.backward()
    optimizer.step()
    del policy.rewards[:]
    del policy.saved_log_probs[:]


def main():
    running_reward = 0
    b = 0
    for i_episode in range(10000):
        tot_rew = 0
        state = env.reset()
        done = False
        while not done:
            action = select_action(state)
            state, reward, done, _ = env.step(action)
            if render:
                env.render()
            policy.rewards.append(reward)
            tot_rew += reward
            if done:
                break
        rew_ep.append(tot_rew)
        running_reward = running_reward * 0.99 + tot_rew * 0.01
        b += (tot_rew-b)/(i_episode+1)
        finish_episode(b)
        if i_episode % log_interval == 0:
            print('Episode {}\tLast Reward: {:2f}\tAverage Reward: {:.2f}'.format(
                i_episode, tot_rew, running_reward))
        if running_reward > env.spec.reward_threshold:
            print("Solved! Running reward is now {} and "
                  "the last episode gives {} !".format(running_reward, tot_rew))
            break

# %%
main()
# Out:
# Episode 0	Last Reward: 11.000000	Average Reward: 0.11
# Episode 10	Last Reward: 26.000000	Average Reward: 4.57
# Episode 20	Last Reward: 175.000000	Average Reward: 12.60
# Episode 30	Last Reward: 29.000000	Average Reward: 15.30
# Episode 40	Last Reward: 46.000000	Average Reward: 17.81
# Episode 50	Last Reward: 200.000000	Average Reward: 26.76
# Episode 60	Last Reward: 108.000000	Average Reward: 34.61
# Episode 70	Last Reward: 150.000000	Average Reward: 40.79
# Episode 80	Last Reward: 200.000000	Average Reward: 49.79
# Episode 90	Last Reward: 200.000000	Average Reward: 63.85
# Episode 100	Last Reward: 164.000000	Average Reward: 74.38
# Episode 110	Last Reward: 110.000000	Average Reward: 79.95
# Episode 120	Last Reward: 200.000000	Average Reward: 89.47
# Episode 130	Last Reward: 200.000000	Average Reward: 100.04
# Episode 140	Last Reward: 200.000000	Average Reward: 109.09
# Episode 150	Last Reward: 200.000000	Average Reward: 117.78
# Episode 160	Last Reward: 12.000000	Average Reward: 114.09
# Episode 170	Last Reward: 24.000000	Average Reward: 104.84
# Episode 180	Last Reward: 28.000000	Average Reward: 97.09
# Episode 190	Last Reward: 37.000000	Average Reward: 90.71
# Episode 200	Last Reward: 96.000000	Average Reward: 87.72
# Episode 210	Last Reward: 126.000000	Average Reward: 89.95
# Episode 220	Last Reward: 200.000000	Average Reward: 97.51
# Episode 230	Last Reward: 187.000000	Average Reward: 105.17
# Episode 240	Last Reward: 200.000000	Average Reward: 114.23
# Episode 250	Last Reward: 200.000000	Average Reward: 122.44
# Episode 260	Last Reward: 200.000000	Average Reward: 129.85
# Episode 270	Last Reward: 166.000000	Average Reward: 135.99
# Episode 280	Last Reward: 89.000000	Average Reward: 134.79
# Episode 290	Last Reward: 111.000000	Average Reward: 130.80
# Episode 300	Last Reward: 162.000000	Average Reward: 131.40
# Episode 310	Last Reward: 200.000000	Average Reward: 137.69
# Episode 320	Last Reward: 164.000000	Average Reward: 141.47
# Episode 330	Last Reward: 154.000000	Average Reward: 144.40
# Episode 340	Last Reward: 176.000000	Average Reward: 148.22
# Episode 350	Last Reward: 164.000000	Average Reward: 151.59
# Episode 360	Last Reward: 200.000000	Average Reward: 155.90
# Episode 370	Last Reward: 188.000000	Average Reward: 159.73
# Episode 380	Last Reward: 171.000000	Average Reward: 162.19
# Episode 390	Last Reward: 163.000000	Average Reward: 161.73
# Episode 400	Last Reward: 200.000000	Average Reward: 164.27
# Episode 410	Last Reward: 200.000000	Average Reward: 167.69
# Episode 420	Last Reward: 200.000000	Average Reward: 170.78
# Episode 430	Last Reward: 200.000000	Average Reward: 173.57
# Episode 440	Last Reward: 200.000000	Average Reward: 176.10
# Episode 450	Last Reward: 200.000000	Average Reward: 178.38
# Episode 460	Last Reward: 142.000000	Average Reward: 176.90
# Episode 470	Last Reward: 153.000000	Average Reward: 173.90
# Episode 480	Last Reward: 157.000000	Average Reward: 172.88
# Episode 490	Last Reward: 190.000000	Average Reward: 173.92
# Episode 500	Last Reward: 200.000000	Average Reward: 175.67
# Episode 510	Last Reward: 200.000000	Average Reward: 177.99
# Episode 520	Last Reward: 200.000000	Average Reward: 180.10
# Episode 530	Last Reward: 200.000000	Average Reward: 182.00
# Episode 540	Last Reward: 200.000000	Average Reward: 183.72
# Episode 550	Last Reward: 200.000000	Average Reward: 185.28
# Episode 560	Last Reward: 200.000000	Average Reward: 186.69
# Episode 570	Last Reward: 200.000000	Average Reward: 187.96
# Episode 580	Last Reward: 200.000000	Average Reward: 189.11
# Episode 590	Last Reward: 200.000000	Average Reward: 190.15
# Episode 600	Last Reward: 200.000000	Average Reward: 191.09
# Episode 610	Last Reward: 200.000000	Average Reward: 191.95
# Episode 620	Last Reward: 200.000000	Average Reward: 192.72
# Episode 630	Last Reward: 200.000000	Average Reward: 193.41
# Episode 640	Last Reward: 200.000000	Average Reward: 194.04
# Episode 650	Last Reward: 200.000000	Average Reward: 194.61
# Solved! Running reward is now 195.02796576884626 and the last episode gives 200.0 !

# %%
plt.plot(rew_ep)
plt.xlabel('num_episodes')
plt.ylabel('episode_rewards')
plt.title('Episodic_Rewards vs num_episodes')

plt.savefig('reinforce_b_cartpole')

# %%
mean_rewards = []
for t in range(len(rew_ep)):
        mean_rewards.append(np.mean(rew_ep[max(0, t-50):(t+1)]))
plt.plot(mean_rewards)
plt.show()
