# %%
import gym
import numpy as np

# %%
env = gym.make("MountainCar-v0")
env._max_episode_steps = 1000

# %%
class Tilecoder:

    def __init__(self, numTilings, tilesPerTiling):
        # Set max value for normalization of inputs
        self.maxNormal = 1
        self.maxVal = env.observation_space.high
        self.minVal = env.observation_space.low
        self.numTilings = numTilings
        self.tilesPerTiling = tilesPerTiling
        self.dim = len(self.maxVal)
        self.numTiles = (self.tilesPerTiling**self.dim) * self.numTilings
        self.actions = env.action_space.n
        self.n = self.numTiles * self.actions
        self.tileSize = np.divide(np.ones(self.dim)*self.maxNormal, self.tilesPerTiling-1)

    def getFeatures(self, variables):
        # Ensures range is always between 0 and self.maxValue
        values = np.zeros(self.dim)
        for i in range(len(env.observation_space.shape)+1):
            values[i] = self.maxNormal * ((variables[i] - self.minVal[i])/(self.maxVal[i]-self.minVal[i]))
        tileIndices = np.zeros(self.numTilings)
        matrix = np.zeros([self.numTilings,self.dim])
        for i in range(self.numTilings):
            for i2 in range(self.dim):
                matrix[i,i2] = int(values[i2] / self.tileSize[i2] + i / self.numTilings)
        for i in range(1,self.dim):
            matrix[:,i] *= self.tilesPerTiling**i
        for i in range(self.numTilings):
            tileIndices[i] = (i * (self.tilesPerTiling**self.dim) + sum(matrix[i,:])) 
        return tileIndices

    def oneHotVector(self, features, action):
        oneHot = np.zeros(self.n)
        for i in features:
            index = int(i + (self.numTiles*action))
            oneHot[index] = 1
        return oneHot

    def getVal(self, theta, features, action):
        val = 0 
        for i in features:
            index = int(i + (self.numTiles*action))
            val += theta[index]
        return val

    def getQ(self, features, theta):
        Q = np.zeros(self.actions)
        for i in range(self.actions):
            Q[i] = tile.getVal(theta, features, i)
        return Q

# %%
    tile = Tilecoder(7,14)
    theta = np.random.uniform(-0.001, 0, size=(tile.n))
    alpha = (.1/ tile.numTilings)*3.2
    gamma = 1
    numEpisodes = 100000
    rewardTracker = []
    episodeSum = 0
    counter = 0 
    eps = 0.5

    for episodeNum in range(1,numEpisodes+1):
        G = 0
        state = env.reset()
        while True:
            #env.render()
            F = tile.getFeatures(state)
            Q = tile.getQ(F, theta)
            action = np.argmax(Q) if np.random.random() > eps \
                                    else np.random.choice([0,1,2])
            state2, reward, done, info = env.step(action)
            G += reward
            delta = reward - Q[action]
            if done == True:
                theta += np.multiply((alpha*delta), tile.oneHotVector(F,action))
                episodeSum += G
                rewardTracker.append(G)
                if episodeNum %100 == 0:
                    print('Average reward = {}'.format(episodeSum / 100))
                    episodeSum = 0
                break
            Q = tile.getQ(tile.getFeatures(state2), theta)
            action_ = np.argmax(Q) if np.random.random() > eps \
                                    else np.random.choice([0,1,2])
            delta += gamma*(Q[action_])
            theta += np.multiply((alpha*delta), tile.oneHotVector(F,action))
            state = state2

        if episodeNum > 100:
            if sum(rewardTracker[episodeNum-100:episodeNum])/100 >= -110:
                print('Solve in {} Episodes'.format(episodeNum))
                break
        eps = eps-4/numEpisodes if eps > 0.01 else 0.01
# Out:
# Average reward = -453.48
# Average reward = -278.71
# Average reward = -249.65
# Average reward = -236.13
# Average reward = -232.12
# Average reward = -227.55
# Average reward = -227.79
# Average reward = -229.85
# Average reward = -232.9
# Average reward = -220.82
# Average reward = -216.99
# Average reward = -212.38
# Average reward = -214.22
# Average reward = -205.65
# Average reward = -214.12
# Average reward = -227.74
# Average reward = -207.76
# Average reward = -214.85
# Average reward = -211.12
# Average reward = -208.09
# Average reward = -201.53
# Average reward = -199.79
# Average reward = -206.57
# Average reward = -199.72
# Average reward = -201.41
# Average reward = -203.92
# Average reward = -193.32
# Average reward = -190.63
# Average reward = -189.63
# Average reward = -194.1
# Average reward = -184.76
# Average reward = -199.5
# Average reward = -193.4
# Average reward = -190.62
# Average reward = -189.5
# Average reward = -191.29
# Average reward = -185.64
# Average reward = -187.9
# Average reward = -172.57
# Average reward = -177.88
# Average reward = -180.7
# Average reward = -172.64
# Average reward = -176.63
# Average reward = -176.21
# Average reward = -175.42
# Average reward = -172.98
# Average reward = -167.07
# Average reward = -174.36
# Average reward = -172.69
# Average reward = -168.47
# Average reward = -168.55
# Average reward = -170.81
# Average reward = -175.0
# Average reward = -170.1
# Average reward = -170.3
# Average reward = -164.49
# Average reward = -157.49
# Average reward = -169.68
# Average reward = -156.38
# Average reward = -158.19
# Average reward = -163.31
# Average reward = -161.23
# Average reward = -159.25
# Average reward = -161.51
# Average reward = -158.21
# Average reward = -158.37
# Average reward = -160.49
# Average reward = -152.04
# Average reward = -160.91
# Average reward = -153.29
# Average reward = -160.12
# Average reward = -153.96
# Average reward = -149.49
# Average reward = -149.62
# Average reward = -152.13
# Average reward = -147.32
# Average reward = -152.25
# Average reward = -147.86
# Average reward = -145.34
# Average reward = -155.36
# Average reward = -146.26
# Average reward = -140.66
# Average reward = -146.35
# Average reward = -146.78
# Average reward = -140.52
# Average reward = -146.99
# Average reward = -142.89
# Average reward = -139.95
# Average reward = -139.32
# Average reward = -146.43
# Average reward = -143.12
# Average reward = -138.83
# Average reward = -134.57
# Average reward = -131.5
# Average reward = -130.57
# Average reward = -134.33
# Average reward = -133.74
# Average reward = -130.77
# Average reward = -137.88
# Average reward = -136.28
# Average reward = -132.85
# Average reward = -136.81
# Average reward = -125.57
# Average reward = -128.03
# Average reward = -127.98
# Average reward = -124.39
# Average reward = -126.6
# Average reward = -128.14
# Average reward = -121.34
# Average reward = -117.51
# Average reward = -124.08
# Average reward = -129.11
# Average reward = -116.6
# Average reward = -122.06
# Average reward = -116.78
# Average reward = -126.19
# Average reward = -122.47
# Average reward = -119.28
# Average reward = -120.68
# Solve in 11998 Episodes

# %%
import matplotlib.pyplot as plt

plt.plot(rewardTracker)
plt.title("Avg_Episodic_Reward vs num_episodes")
plt.xlabel("Num_episode")
plt.ylabel("Avg_episodic_Reward")
plt.savefig('tile_coding_sarsa_mc')
